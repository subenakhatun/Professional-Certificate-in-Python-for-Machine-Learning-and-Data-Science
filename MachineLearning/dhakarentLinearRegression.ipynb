# %% [markdown]
# # Step-01: import all file

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Dhaka Rent.csv', sep=";")
df.head()
# Out:
#    area   rent
# 0  2000  31500
# 1  2100  35000
# 2  2500  41050
# 3  2250  36100
# 4  3000  52100

# %%
# Row implementation process

# %% [markdown]
# # Row Implementation Process
# 1. Calculate the mean of x and y <br>
# 2. Calculate the slope(m):<br>
# 3. Calculate the y-intercept. <br>
# 4. Predict the value for x = 3200 <br>
# 5. Show the calculated slope, intercept and the predicted value of y.

# %%
# assign x and y
x = df['area']
y = df['rent']

# %%
# at first see all the data in plot
plt.scatter(x,y, color="red")
plt.xlabel("Area sqrtft")
plt.ylabel("Rent per sqrtft area.")
# Out:
# Text(0, 0.5, 'Rent per sqrtft area.')

# %%
# mean of x and y
mean_x = np.mean(x)
mean_x
# Out:
# np.float64(2289.0)

# %%
mean_y = np.mean(y)
mean_y
# Out:
# np.float64(37269.166666666664)

# %%
# claculate the slope
numerator = ((x-mean_x)*(y-mean_y)).sum()
numerator
# Out:
# np.float64(364810149.99999994)

# %%
denominator = ((x-mean_x)**2).sum()
denominator
# Out:
# np.float64(17133140.0)

# %%
slope_m = numerator/denominator
slope_m
# Out:
# np.float64(21.292661473611954)

# %%
# intercept = mean_y - slope*mean_x
intercept_y = mean_y - slope_m*mean_x
intercept_y
# Out:
# np.float64(-11469.7354464311)

# %%
# predict the value , y = mx + c
# x = 32000
x_pridicted_value = 32000
y_predict = slope_m*x_pridicted_value+intercept_y
y_predict
# Out:
# np.float64(669895.4317091515)

# %%
# find all dataset relation or y-predicted value
predicted = slope_m*x+intercept_y
predicted
# Out:
# 0     31115.587501
# 1     33244.853648
# 2     41761.918238
# 3     36438.752869
# 4     52408.248974
# 5     28986.321353
# 6     20469.256764
# 7     27921.688280
# 8     46020.450532
# 9     33244.853648
# 10    34309.486722
# 11    33244.853648
# 12    33244.853648
# 13    41974.844852
# 14    36438.752869
# 15    54537.515122
# 16    26857.055206
# 17    21533.889838
# 18    26857.055206
# 19    46020.450532
# 20    33457.780263
# 21    33244.853648
# 22    63054.579711
# 23    14081.458322
# 24    48149.716680
# 25    54537.515122
# 26    47085.083606
# 27    26857.055206
# 28    35374.119796
# 29    54537.515122
# 30    33244.853648
# 31    33244.853648
# 32    41761.918238
# 33    36438.752869
# 34    52408.248974
# 35    28986.321353
# 36    20469.256764
# 37    27921.688280
# 38    46020.450532
# 39    33244.853648
# 40    34309.486722
# 41    33244.853648
# 42    33244.853648
# 43    41974.844852
# 44    36438.752869
# 45    54537.515122
# 46    26857.055206
# 47    21533.889838
# 48    26857.055206
# 49    46020.450532
# 50    33457.780263
# 51    33244.853648
# 52    63054.579711
# 53    14081.458322
# 54    48149.716680
# 55    54537.515122
# 56    47085.083606
# 57    26857.055206
# 58    35374.119796
# 59    54537.515122
# Name: area, dtype: float64

# %%
# add predicted value into dataset
df['Predicted'] = predicted
df.head()
# Out:
#    area   rent     Predicted
# 0  2000  31500  31115.587501
# 1  2100  35000  33244.853648
# 2  2500  41050  41761.918238
# 3  2250  36100  36438.752869
# 4  3000  52100  52408.248974

# %%
# now show data with predicted
plt.plot(x,predicted)
plt.scatter(x,y, color="red")
plt.scatter(x,predicted, color="green")
plt.xlabel("Area sqrtft")
plt.ylabel("Rent per sqrtft area.")
# Out:
# Text(0, 0.5, 'Rent per sqrtft area.')

# %% [markdown]
# # Now find Error or cost function.
# error = average actual - averag predicted of y value . <br>
# 1. mse <br>
# 2. mae <br>
# 3. mrse

# %%
# resiual or error = acutal y = predicted y. for single data point
# cost/error = average actual y - average predicted y

# %% [markdown]
# # Using sk learn

# %%
from sklearn.linear_model import LinearRegression

# %%
# Crete regression object
reg = LinearRegression()
reg
# Out:
# LinearRegression()

# %%
# fit means train your data.
reg.fit(df[['area']],y)
# Out:
# LinearRegression()

# %%
reg.predict([[32000]])
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([669895.43170915])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse = mean_squared_error(y,predicted)
mse
# Out:
# 6778077.204095553

# %%
mae = mean_absolute_error(y,predicted)
mae
# Out:
# 2009.8695093576268

# %%
df.corr()
# Out:
#                area      rent  Predicted
# area       1.000000  0.974807   1.000000
# rent       0.974807  1.000000   0.974807
# Predicted  1.000000  0.974807   1.000000
